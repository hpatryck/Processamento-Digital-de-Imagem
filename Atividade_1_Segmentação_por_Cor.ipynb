# %% [markdown]
# <a href="https://colab.research.google.com/github/hpatryck/Processamento-Digital-de-Imagem/blob/main/Atividade_1_Segmenta%C3%A7%C3%A3o_por_Cor.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
from skimage import io
print("OpenCV-Python Version {}".format(cv2.__version__))

from google.colab import drive
drive.mount('/content/drive')
# Out:
# OpenCV-Python Version 4.8.0
# Mounted at /content/drive

# %%
image = io.imread(r'/content/drive/MyDrive/Colab Notebooks/unnamed.png')

io.imsave('image.jpg', image)

# loading the image from the disk
image = cv2.imread('image.jpg')
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

plt.imshow(image)
plt.show()

# Hmin = 0            Hmax = 5
# Smin = 49           Smax = 255
# Vmin = 0            Vmax = 255

# %%
image = io.imread(r'/content/drive/MyDrive/Colab Notebooks/unnamed.png')

io.imsave('image.jpg', image)

# loading the image from the disk
image = cv2.imread('image.jpg')
image = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)
#image = cv2.cvtColor(image, cv2.COLOR_RGB2HSV)

vmin = np.array([0, 49, 0])
vmax = np.array([5, 255, 255])

mask = cv2.inRange(image, vmin, vmax)

image = cv2.bitwise_and(image, image, mask = mask)
image = cv2.cvtColor(image, cv2.COLOR_HSV2RGB)

plt.imshow(image)
plt.show()
